# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from Bottom_Up_Segmentation import *

# %% [markdown]
# ### Reading the data by specifying a path. In the UI, the user will upload a file instead.

# %%
ts_arr = pd.read_csv('../../DDP/Code- Segmentation Pipeline and Results/Datasets_csv/Pressure/Sheet1.csv')['PSPCKL'].dropna().to_numpy() 
ts_name = 'PSPCKL- Sheet 1'

# %% [markdown]
# ### In the UI, take these parameters as input from the user

# %%
num_windows, lambda_param = 100, 1.0

# %% [markdown]
# ### How to use the imported class- Train the segmentation model and plot the result. This plot should be displayed in the UI

# %%
seg_model_obj = Bottom_Up_Segmentation(num_windows, lambda_param)
seg_model_obj.train_model(ts_arr)

# %%
seg_model_obj.plot_segmentation(ts_name)
